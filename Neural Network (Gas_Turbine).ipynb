# %%
# import libreries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
import keras
import tensorflow as tf
import sklearn

# %%
data=pd.read_csv("gas_turbines.csv")

# %%
data
# Out:
#            AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0      6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1      6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2      6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3      7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4      7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
# ...       ...     ...     ...     ...     ...     ...     ...     ...     ...
# 15034  9.0301  1005.6  98.460  3.5421  19.164  1049.7  546.21  111.61  10.400
# 15035  7.8879  1005.9  99.093  3.5059  19.414  1046.3  543.22  111.78  10.433
# 15036  7.2647  1006.3  99.496  3.4770  19.530  1037.7  537.32  110.19  10.483
# 15037  7.0060  1006.8  99.008  3.4486  19.377  1043.2  541.24  110.74  10.533
# 15038  6.9279  1007.2  97.533  3.4275  19.306  1049.9  545.85  111.58  10.583
#
#            CO     NOX
# 0      3.1547  82.722
# 1      3.2363  82.776
# 2      3.2012  82.468
# 3      3.1923  82.670
# 4      3.2484  82.311
# ...       ...     ...
# 15034  4.5186  79.559
# 15035  4.8470  79.917
# 15036  7.9632  90.912
# 15037  6.2494  93.227
# 15038  4.9816  92.498
#
# [15039 rows x 11 columns]

# %%
data.head()
# Out:
#        AT      AP      AH    AFDP    GTEP     TIT     TAT     TEY     CDP  \
# 0  6.8594  1007.9  96.799  3.5000  19.663  1059.2  550.00  114.70  10.605
# 1  6.7850  1008.4  97.118  3.4998  19.728  1059.3  550.00  114.72  10.598
# 2  6.8977  1008.8  95.939  3.4824  19.779  1059.4  549.87  114.71  10.601
# 3  7.0569  1009.2  95.249  3.4805  19.792  1059.6  549.99  114.72  10.606
# 4  7.3978  1009.7  95.150  3.4976  19.765  1059.7  549.98  114.72  10.612
#
#        CO     NOX
# 0  3.1547  82.722
# 1  3.2363  82.776
# 2  3.2012  82.468
# 3  3.1923  82.670
# 4  3.2484  82.311

# %%
data.shape
# Out:
# (15039, 11)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15039 entries, 0 to 15038
# Data columns (total 11 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   AT      15039 non-null  float64
#  1   AP      15039 non-null  float64
#  2   AH      15039 non-null  float64
#  3   AFDP    15039 non-null  float64
#  4   GTEP    15039 non-null  float64
#  5   TIT     15039 non-null  float64
#  6   TAT     15039 non-null  float64
#  7   TEY     15039 non-null  float64
#  8   CDP     15039 non-null  float64
#  9   CO      15039 non-null  float64
#  10  NOX     15039 non-null  float64
# dtypes: float64(11)
# memory usage: 1.3 MB

# %%
data.describe()
# Out:
#                  AT           AP            AH          AFDP          GTEP  \
# count  15039.000000  15039.00000  15039.000000  15039.000000  15039.000000
# mean      17.764381   1013.19924     79.124174      4.200294     25.419061
# std        7.574323      6.41076     13.793439      0.760197      4.173916
# min        0.522300    985.85000     30.344000      2.087400     17.878000
# 25%       11.408000   1008.90000     69.750000      3.723900     23.294000
# 50%       18.186000   1012.80000     82.266000      4.186200     25.082000
# 75%       23.862500   1016.90000     90.043500      4.550900     27.184000
# max       34.929000   1034.20000    100.200000      7.610600     37.402000
#
#                 TIT           TAT           TEY           CDP            CO  \
# count  15039.000000  15039.000000  15039.000000  15039.000000  15039.000000
# mean    1083.798770    545.396183    134.188464     12.102353      1.972499
# std       16.527806      7.866803     15.829717      1.103196      2.222206
# min     1000.800000    512.450000    100.170000      9.904400      0.000388
# 25%     1079.600000    542.170000    127.985000     11.622000      0.858055
# 50%     1088.700000    549.890000    133.780000     12.025000      1.390200
# 75%     1096.000000    550.060000    140.895000     12.578000      2.160400
# max     1100.800000    550.610000    174.610000     15.081000     44.103000
#
#                 NOX
# count  15039.000000
# mean      68.190934
# std       10.470586
# min       27.765000
# 25%       61.303500
# 50%       66.601000
# 75%       73.935500
# max      119.890000

# %%
data.dtypes
# Out:
# AT      float64
# AP      float64
# AH      float64
# AFDP    float64
# GTEP    float64
# TIT     float64
# TAT     float64
# TEY     float64
# CDP     float64
# CO      float64
# NOX     float64
# dtype: object

# %% [markdown]
# # Data Analysis And Visualisation

# %%
data.columns
# Out:
# Index(['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'TEY', 'CDP', 'CO',
#        'NOX'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings("ignore")
fig, axes = plt.subplots(5, 2, figsize=(20, 15))
fig.suptitle('Univariate Analysis',fontsize=20)
sns.distplot(data['AT'],ax=axes[0,0],color='indigo')
sns.distplot(data['AP'],ax=axes[0,1],color='orange')
sns.distplot(data['AH'],ax=axes[1,0],color='indigo')
sns.distplot(data['AFDP'],ax=axes[1,1],color='orange')
sns.distplot(data['GTEP'],ax=axes[2,0],color='indigo')
sns.distplot(data['TIT'],ax=axes[2,1],color='orange')
sns.distplot(data['TAT'],ax=axes[3,0],color='indigo')
sns.distplot(data['CDP'],ax=axes[3,1],color='orange')
sns.distplot(data['CO'],ax=axes[4,0],color='indigo')
sns.distplot(data['NOX'],ax=axes[4,1],color='orange')
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='Density'>

# %% [markdown]
# #### inferences drawn :
# #### 1. Left Skewness : AH/TIT/TAT
# #### 2. Right Skewness : AFDP/CO
# #### 3. NOX seems to have normally distribution

# %%
sns.distplot(data['TEY'],color='red')
# Out:
# <AxesSubplot:xlabel='TEY', ylabel='Density'>

# %%
import warnings
warnings.filterwarnings("ignore")
fig, axes = plt.subplots(5, 2, figsize=(20, 20))
fig.suptitle('Bivariate Analysis',fontsize=20)
sns.regplot(x="AT",y="TEY",data=data,ax=axes[0,0],color='indigo')
sns.regplot(x="AP",y="TEY",data=data,ax=axes[0,1],color='orange')
sns.regplot(x="AH",y="TEY",data=data,ax=axes[1,0],color='indigo')
sns.regplot(x="AFDP",y="TEY",data=data,ax=axes[1,1],color='orange')
sns.regplot(x="GTEP",y="TEY",data=data,ax=axes[2,0],color='indigo')
sns.regplot(x="TIT",y="TEY",data=data,ax=axes[2,1],color='orange')
sns.regplot(x="TAT",y="TEY",data=data,ax=axes[3,0],color='indigo')
sns.regplot(x="CDP",y="TEY",data=data,ax=axes[3,1],color='orange')
sns.regplot(x="CO",y="TEY",data=data,ax=axes[4,0],color='indigo')
sns.regplot(x="NOX",y="TEY",data=data,ax=axes[4,1],color='orange')
# Out:
# <AxesSubplot:xlabel='NOX', ylabel='TEY'>

# %%
fig, axes = plt.subplots(figsize=(10, 8))
sns.heatmap(data.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
# Defining Independent and Dependent Variables
X = data.loc[:,['AT', 'AP', 'AH', 'AFDP', 'GTEP', 'TIT', 'TAT', 'CDP', 'CO','NOX']]
y= data.loc[:,['TEY']]

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler = StandardScaler()
X = scaler.fit_transform(X)
y = scaler.fit_transform(y)

# %%
from keras.models import Sequential
from keras.layers import InputLayer,Dense

# %%
def baseline_model():
    model = Sequential()
    model.add(Dense(10, input_dim=10, activation='tanh'))
    model.add(Dense(1))
    model.compile(loss='mean_squared_error', optimizer='adam')
    return model

# %%
from keras.wrappers.scikit_learn import KerasRegressor

# %%
from sklearn.model_selection import KFold

# %%
from sklearn.model_selection import cross_val_score

# %%
estimator = KerasRegressor(build_fn=baseline_model, nb_epoch=50, batch_size=100, verbose=False)
kfold = KFold(n_splits=10)
results = cross_val_score(estimator, X, y, cv=kfold)
print("Results: %.2f (%.2f) MSE" % (results.mean(), results.std()))
# Out:
# Results: -0.17 (0.17) MSE

# %%
estimator.fit(X, y)
prediction = estimator.predict(X)

# %%
prediction
# Out:
# array([-1.0176923, -1.0356656, -1.0568489, ..., -1.2363138, -1.0640949,
#        -0.8997113], dtype=float32)

# %%
X = data.drop(columns = ['TEY'], axis = 1) 
y = data.iloc[:,7]

# %%
from sklearn.model_selection import train_test_split

# %%
from sklearn.preprocessing import scale
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.1, random_state = 42)
X_train_scaled = scale(X_train)
X_test_scaled = scale(X_test)
X_test_scaled
# Out:
# array([[ 0.82623246, -0.43954308, -0.25924569, ...,  0.10039242,
#         -0.3796304 , -0.69217007],
#        [ 0.35282087,  0.23279782,  0.80230139, ..., -1.18541222,
#          0.39149515, -1.09475442],
#        [ 0.32839008, -0.07135639,  0.25312287, ...,  0.01665304,
#         -0.00296896, -0.31891741],
#        ...,
#        [-0.74071701,  0.37687087,  0.43427425, ...,  1.77157829,
#         -1.00127821, -0.4818816 ],
#        [-0.49965786, -0.39151873,  0.64680105, ..., -0.26517949,
#         -0.48137538,  0.12808615],
#        [ 0.13151427,  0.32884652,  0.98830762, ..., -1.40331469,
#          0.13152215, -0.64456466]])

# %%
import tensorflow as tf
input_size = len(X.columns)
output_size = 1
hidden_layer_size = 50

model = tf.keras.Sequential([
                                
                               tf.keras.layers.Dense(hidden_layer_size, input_dim = input_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),
                               tf.keras.layers.Dense(hidden_layer_size, activation = 'relu'),     
                               tf.keras.layers.Dense(output_size)
                             ])

# %%
optimizer = tf.keras.optimizers.SGD(learning_rate = 0.03)
model.compile(optimizer = 'adam', loss = 'mean_squared_error', metrics = ['MeanSquaredError'])

# %%
num_epochs = 100
early_stopping = tf.keras.callbacks.EarlyStopping(patience = 2)
model.fit(X_train_scaled, y_train, callbacks = early_stopping, validation_split = 0.1, epochs = num_epochs, verbose = 2)
# Out:
# Epoch 1/100
# 381/381 - 1s - loss: 2925.4368 - mean_squared_error: 2925.4368 - val_loss: 194.0088 - val_mean_squared_error: 194.0088 - 1s/epoch - 4ms/step
# Epoch 2/100
# 381/381 - 1s - loss: 107.4223 - mean_squared_error: 107.4223 - val_loss: 87.9740 - val_mean_squared_error: 87.9740 - 672ms/epoch - 2ms/step
# Epoch 3/100
# 381/381 - 1s - loss: 47.4117 - mean_squared_error: 47.4117 - val_loss: 37.2131 - val_mean_squared_error: 37.2131 - 664ms/epoch - 2ms/step
# Epoch 4/100
# 381/381 - 1s - loss: 23.0538 - mean_squared_error: 23.0538 - val_loss: 18.0781 - val_mean_squared_error: 18.0781 - 674ms/epoch - 2ms/step
# Epoch 5/100
# 381/381 - 1s - loss: 11.3945 - mean_squared_error: 11.3945 - val_loss: 10.5945 - val_mean_squared_error: 10.5945 - 705ms/epoch - 2ms/step
# Epoch 6/100
# 381/381 - 1s - loss: 5.9175 - mean_squared_error: 5.9175 - val_loss: 5.2065 - val_mean_squared_error: 5.2065 - 665ms/epoch - 2ms/step
# Epoch 7/100
# 381/381 - 1s - loss: 3.8105 - mean_squared_error: 3.8105 - val_loss: 3.7308 - val_mean_squared_error: 3.7308 - 709ms/epoch - 2ms/step
# Epoch 8/100
# 381/381 - 1s - loss: 2.4753 - mean_squared_error: 2.4753 - val_loss: 1.9458 - val_mean_squared_error: 1.9458 - 665ms/epoch - 2ms/step
# Epoch 9/100
# 381/381 - 1s - loss: 1.8947 - mean_squared_error: 1.8947 - val_loss: 1.8630 - val_mean_squared_error: 1.8630 - 661ms/epoch - 2ms/step
# Epoch 10/100
# 381/381 - 1s - loss: 1.7515 - mean_squared_error: 1.7515 - val_loss: 1.7388 - val_mean_squared_error: 1.7388 - 662ms/epoch - 2ms/step
# Epoch 11/100
# 381/381 - 1s - loss: 1.3563 - mean_squared_error: 1.3563 - val_loss: 1.2867 - val_mean_squared_error: 1.2867 - 667ms/epoch - 2ms/step
# Epoch 12/100
# 381/381 - 1s - loss: 1.1661 - mean_squared_error: 1.1661 - val_loss: 1.1716 - val_mean_squared_error: 1.1716 - 700ms/epoch - 2ms/step
# Epoch 13/100
# 381/381 - 1s - loss: 1.1707 - mean_squared_error: 1.1707 - val_loss: 1.1014 - val_mean_squared_error: 1.1014 - 668ms/epoch - 2ms/step
# Epoch 14/100
# 381/381 - 1s - loss: 0.9865 - mean_squared_error: 0.9865 - val_loss: 0.8505 - val_mean_squared_error: 0.8505 - 677ms/epoch - 2ms/step
# Epoch 15/100
# 381/381 - 1s - loss: 0.9954 - mean_squared_error: 0.9954 - val_loss: 1.3042 - val_mean_squared_error: 1.3042 - 676ms/epoch - 2ms/step
# Epoch 16/100
# 381/381 - 1s - loss: 0.9334 - mean_squared_error: 0.9334 - val_loss: 0.9484 - val_mean_squared_error: 0.9484 - 657ms/epoch - 2ms/step

# %%
test_loss, mean_squared_error = model.evaluate(X_test_scaled, y_test)
# Out:
# 47/47 [==============================] - 0s 2ms/step - loss: 0.8823 - mean_squared_error: 0.8823

# %%
predictions = model.predict_on_batch(X_test_scaled)

# %%
plt.scatter(y_test, predictions)

# %%
predictions_df = pd.DataFrame()
predictions_df['Actual'] = y_test
predictions_df['Predicted'] = predictions
predictions_df['% Error'] = abs(predictions_df['Actual'] - predictions_df['Predicted'])/predictions_df['Actual']*100
predictions_df.reset_index(drop = True)
# Out:
#       Actual   Predicted   % Error
# 0     134.46  134.817078  0.265564
# 1     111.88  112.702751  0.735387
# 2     133.72  134.585754  0.647438
# 3     133.79  133.980423  0.142330
# 4     110.77  111.874535  0.997142
# ...      ...         ...       ...
# 1499  132.85  133.483093  0.476547
# 1500  125.07  125.860924  0.632385
# 1501  160.95  161.397552  0.278069
# 1502  133.12  133.507431  0.291039
# 1503  111.79  112.609474  0.733048
#
# [1504 rows x 3 columns]
